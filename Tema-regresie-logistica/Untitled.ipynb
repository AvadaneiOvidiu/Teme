# %%
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
x=np.linspace(-10,10,100)
l= lambda s: 1/(1+math.exp(-s))

sigmoid=np.vectorize(l)
y=sigma(x)
plt.plot(x,y,label="sigmoid")
def sigma1(s):
    return 1/(1+math.exp(-s+1.0))
sigmoid1=np.vectorize(sigma1)
y1=sigmoid1(x)
plt.plot(x,y1,label="sigmoid1")
def sigma2(s):
    return 1/(1+math.exp(-s-2.5))
sigmoid2=np.vectorize(sigma2)
y2=sigmoid2(x)
plt.plot(x,y2,label="sigmoid2")
plt.show()
